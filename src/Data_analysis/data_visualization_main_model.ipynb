# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_main_model = pd.read_excel('../../Dataset/processed_data/DataMain.xlsx')
data_main_model.head()
# Out:
#    Year  Country  Energy_Emissions  Industrial_Process_Emissions  \
# 0  2005  Belgium       77556.75026                   20906.04220
# 1  1995  Belgium       83269.45074                   19941.63571
# 2  2010  Belgium       70700.54292                   16092.45295
# 3  2015  Belgium       57502.20974                   15374.60312
# 4  1990  Belgium       80990.65980                   18459.45087
#
#    Land_Use_Emissions  Transport_Emissions  Total CO2 Emissions
# 0         -1609.97077          26347.49235         129088.85789
# 1         -2658.35710          22519.48015         128988.79819
# 2          -432.82334          26168.14528         117996.41285
# 3          -446.96952          26404.07750         104148.42064
# 4         -3325.10286          20553.75883         123607.36718

# %%
data_main_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 407 entries, 0 to 406
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          407 non-null    int64
#  1   Country                       407 non-null    object
#  2   Energy_Emissions              406 non-null    float64
#  3   Industrial_Process_Emissions  406 non-null    float64
#  4   Land_Use_Emissions            406 non-null    float64
#  5   Transport_Emissions           406 non-null    float64
#  6   Total CO2 Emissions           406 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 22.4+ KB

# %%
X = data_main_model.to_numpy()
X.shape
# Out:
# (407, 7)

# %%
plt.figure(figsize=(8, 4))
sns.distplot(data_main_model['Total CO2 Emissions'])
plt.xlabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_dist_plot.pdf')
plt.figure(figsize=(10, 4))
sns.lineplot(x='Year', y='Total CO2 Emissions', hue='Country', data=data_main_model)
plt.ylabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_vs_year.pdf')

# %%
plt.figure(figsize=(8, 4))
sns.distplot(data_main_model['Transport_Emissions'])
plt.xlabel('Transport sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/transport_emissions_dist_plot.pdf')
plt.figure(figsize=(10, 4))
sns.lineplot(x='Year', y='Transport_Emissions', hue='Country', data=data_main_model)
plt.ylabel('Transport sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/transport_emissions_vs_year.pdf')

# %%
plt.figure(figsize=(8, 4))
sns.distplot(data_main_model['Land_Use_Emissions'])
plt.xlabel('Land-use sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/landuse_emissions_dist_plot.pdf')
plt.figure(figsize=(10, 4))
sns.lineplot(x='Year', y='Land_Use_Emissions', hue='Country', data=data_main_model)
plt.ylabel('Land-use sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/landuse_emissions_vs_year.pdf')

# %%
plt.figure(figsize=(8, 4))
sns.distplot(data_main_model['Industrial_Process_Emissions'])
plt.xlabel('Industrial Process sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/industrial_emissions_dist_plot.pdf')
plt.figure(figsize=(10, 4))
sns.lineplot(x='Year', y='Industrial_Process_Emissions', hue='Country', data=data_main_model)
plt.ylabel('Industrial Process sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/industrial_emissions_vs_year.pdf')

# %%
plt.figure(figsize=(8, 4))
sns.distplot(data_main_model['Energy_Emissions'])
plt.xlabel('Energy sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/energy_emissions_dist_plot.pdf')
plt.figure(figsize=(10, 4))
sns.lineplot(x='Year', y='Energy_Emissions', hue='Country', data=data_main_model)
plt.ylabel('Energy sector CO2 Emissions (Gg)')
plt.savefig('plots/main_model/energy_emissions_vs_year.pdf')

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(df.corr(), annot= True)
plt.savefig('plots/main_model/heatmap_main_model.pdf')
print("The grids with colour near to white or values near to 1 has high correlations with respective features")
# Out:
# The grids with colour near to white or values near to 1 has high correlations with respective features

# %%
df = data_main_model.drop(columns=['Year'])
# plt.figure(figsize=(30, 15))
# plt.rcParams['figure.figsize'] = 30,30
g = sns.PairGrid(df, hue='Country')
g.fig.set_size_inches(20,15)
g.map(plt.scatter) # for all plots
plt.legend()
plt.savefig('plots/main_model/pairplot.pdf')

# %%
# 0   Year                          378 non-null    int64  
#  1   Country                       378 non-null    object 
#  2   Energy_Emissions              376 non-null    float64
#  3   Industrial_Process_Emissions  376 non-null    float64
#  4   Land_Use_Emissions            377 non-null    float64
#  5   Transport_Emissions           377 non-null    float64
#  6   Total CO2 Emissions

# %%
# plt.figure(figsize=(11, 6))
plt.figure(figsize=(10, 6))Tran
sns.scatterplot(x="Energy_Emissions", y="Total CO2 Emissions", hue="Country", data=data_main_model)
plt.xlabel('Energy sector CO2 Emissions (Gg)')
plt.ylabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_vs_energy_emissions.pdf')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Industrial_Process_Emissions", y="Total CO2 Emissions", hue="Country", data=data_main_model)
plt.xlabel('Industrial process sector CO2 Emissions (Gg)')
plt.ylabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_vs_industrial.pdf')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Transport_Emissions", y="Total CO2 Emissions", hue="Country", data=data_main_model)
plt.xlabel('Transport sector CO2 Emissions (Gg)')
plt.ylabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_vs_transport_emissions.pdf')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="Land_Use_Emissions", y="Total CO2 Emissions", hue="Country", data=data_main_model)
plt.xlabel('Land-use sector CO2 Emissions (Gg)')
plt.ylabel('Total CO2 Emissions (Gg)')
plt.savefig('plots/main_model/total_co2_vs_landuse_emissions.pdf')

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df,palette='rainbow')
plt.savefig('plots/main_model/main_model_boxplot.pdf')
